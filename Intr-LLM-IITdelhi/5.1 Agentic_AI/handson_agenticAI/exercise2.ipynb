# %%
# !pip install llama-index openai
# Out:
# Requirement already satisfied: llama-index in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (0.13.0)
# Requirement already satisfied: openai in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (1.98.0)
# Requirement already satisfied: llama-index-cli<0.6,>=0.5.0 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index) (0.5.0)
# Requirement already satisfied: llama-index-core<0.14,>=0.13.0 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index) (0.13.0)
# Requirement already satisfied: llama-index-embeddings-openai<0.6,>=0.5.0 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index) (0.5.0)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.4.0 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index) (0.9.0)
# Requirement already satisfied: llama-index-llms-openai<0.6,>=0.5.0 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index) (0.5.0)
# Requirement already satisfied: llama-index-readers-file<0.6,>=0.5.0 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index) (0.5.0)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.4.0 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index) (0.5.0)
# Requirement already satisfied: nltk>3.8.1 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index) (3.9.1)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index) (3.12.15)
# Requirement already satisfied: aiosqlite in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index) (0.21.0)
# Requirement already satisfied: banks<3,>=2.2.0 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index) (2.2.0)
# Requirement already satisfied: dataclasses-json in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index) (2025.7.0)
# Requirement already satisfied: httpx in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index) (0.28.1)
# Requirement already satisfied: llama-index-workflows<2,>=1.0.1 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index) (1.2.0)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index) (3.5)
# Requirement already satisfied: numpy in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index) (2.3.2)
# Requirement already satisfied: pillow>=9.0.0 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index) (11.3.0)
# Requirement already satisfied: platformdirs in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index) (4.3.8)
# Requirement already satisfied: pydantic>=2.8.0 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index) (2.11.7)
# Requirement already satisfied: pyyaml>=6.0.1 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index) (6.0.2)
# Requirement already satisfied: requests>=2.31.0 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index) (2.32.4)
# Requirement already satisfied: setuptools>=80.9.0 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index) (80.9.0)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.14,>=0.13.0->llama-index) (2.0.42)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index) (9.1.2)
# Requirement already satisfied: tiktoken>=0.7.0 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index) (0.9.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index) (4.14.1)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index-core<0.14,>=0.13.0->llama-index) (1.17.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.14,>=0.13.0->llama-index) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.14,>=0.13.0->llama-index) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.14,>=0.13.0->llama-index) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.14,>=0.13.0->llama-index) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.14,>=0.13.0->llama-index) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.14,>=0.13.0->llama-index) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.14,>=0.13.0->llama-index) (1.20.1)
# Requirement already satisfied: griffe in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from banks<3,>=2.2.0->llama-index-core<0.14,>=0.13.0->llama-index) (1.9.0)
# Requirement already satisfied: jinja2 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from banks<3,>=2.2.0->llama-index-core<0.14,>=0.13.0->llama-index) (3.1.6)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from openai) (0.10.0)
# Requirement already satisfied: sniffio in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from openai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from httpx->llama-index-core<0.14,>=0.13.0->llama-index) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from httpx->llama-index-core<0.14,>=0.13.0->llama-index) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from httpcore==1.*->httpx->llama-index-core<0.14,>=0.13.0->llama-index) (0.16.0)
# Requirement already satisfied: beautifulsoup4<5,>=4.12.3 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (4.13.4)
# Requirement already satisfied: defusedxml>=0.7.1 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (0.7.1)
# Requirement already satisfied: pandas<2.3.0 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (2.2.3)
# Requirement already satisfied: pypdf<6,>=5.1.0 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (5.9.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (0.0.26)
# Requirement already satisfied: soupsieve>1.2 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from beautifulsoup4<5,>=4.12.3->llama-index-readers-file<0.6,>=0.5.0->llama-index) (2.7)
# Requirement already satisfied: llama-index-instrumentation>=0.1.0 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index-workflows<2,>=1.0.1->llama-index-core<0.14,>=0.13.0->llama-index) (0.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from pandas<2.3.0->llama-index-readers-file<0.6,>=0.5.0->llama-index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from pandas<2.3.0->llama-index-readers-file<0.6,>=0.5.0->llama-index) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from pandas<2.3.0->llama-index-readers-file<0.6,>=0.5.0->llama-index) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.14,>=0.13.0->llama-index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.14,>=0.13.0->llama-index) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.14,>=0.13.0->llama-index) (0.4.1)
# Requirement already satisfied: llama-cloud==0.1.35 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index) (0.1.35)
# Requirement already satisfied: llama-parse>=0.5.0 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-index-readers-llama-parse>=0.4.0->llama-index) (0.6.54)
# Requirement already satisfied: llama-cloud-services>=0.6.54 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (0.6.54)
# Requirement already satisfied: click<9,>=8.1.7 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-cloud-services>=0.6.54->llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (8.2.2)
# Requirement already satisfied: python-dotenv<2,>=1.0.1 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from llama-cloud-services>=0.6.54->llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (1.1.1)
# Requirement already satisfied: joblib in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from nltk>3.8.1->llama-index) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from nltk>3.8.1->llama-index) (2025.7.34)
# Requirement already satisfied: six>=1.5 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<2.3.0->llama-index-readers-file<0.6,>=0.5.0->llama-index) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.14,>=0.13.0->llama-index) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.14,>=0.13.0->llama-index) (2.5.0)
# Requirement already satisfied: greenlet>=1 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.14,>=0.13.0->llama-index) (3.2.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.14,>=0.13.0->llama-index) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from dataclasses-json->llama-index-core<0.14,>=0.13.0->llama-index) (3.26.1)
# Requirement already satisfied: packaging>=17.0 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.14,>=0.13.0->llama-index) (25.0)
# Requirement already satisfied: colorama>=0.4 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from griffe->banks<3,>=2.2.0->llama-index-core<0.14,>=0.13.0->llama-index) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/victor/miniforge3/envs/training/lib/python3.12/site-packages (from jinja2->banks<3,>=2.2.0->llama-index-core<0.14,>=0.13.0->llama-index) (3.0.2)

# %%
from llama_index.core import SimpleDirectoryReader
from llama_index.core import GPTVectorStoreIndex  
from dotenv import load_dotenv

# %%
if load_dotenv() == False:  
    os.environ['OPENAPI_API_KEY'] = ''

# %%
documents = SimpleDirectoryReader("data").load_data()

# %%
index = GPTVectorStoreIndex.from_documents(documents)

# %%
query_engine = index.as_query_engine()  

response = query_engine.query("Who was the CEO of TCS in 2023 and what did he/she say in the annual letter? Share some key highlights.")

print(response)
# Out:
# The CEO of TCS in 2023 was K Krithivasan. In the annual letter, he expressed gratitude for the opportunity to lead the organization and highlighted the strong leadership team and motivated workforce. He mentioned interacting with customers, leadership teams, and employees to understand customer relationships and priorities. Key highlights included sustained focus on cloud adoption, data architecture, customer experience, and business model transformation, as well as commitments to net-zero carbon emissions. Additionally, he emphasized the importance of technology adoption for business growth, investments in building capabilities, and a strong deal flow throughout the year, ending with an order book of $34.1 billion.
